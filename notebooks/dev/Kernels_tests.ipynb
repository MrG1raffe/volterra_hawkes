# %%
# %load_ext autoreload
# %autoreload 2
import sys
if ".." not in sys.path:
    sys.path.append("../../..")

import warnings
import numpy as np
from scipy.integrate import cumulative_trapezoid
from scipy.special import gamma
import matplotlib
import matplotlib.pyplot as plt
from typing import Callable

from volterra_hawkes.kernel.kernels import *
from volterra_hawkes.utility.kernel_functions import mittag_leffler


my_green = "#5b6c64"
my_copper = "#B56246"
plt.rcParams["figure.figsize"]        = ((1 + np.sqrt(5)) / 2 * 5, 5)
plt.rcParams["figure.autolayout"]     = True
plt.rcParams["patch.force_edgecolor"] = False
plt.rcParams["axes.grid"]             = True
plt.rcParams['axes.prop_cycle']       = matplotlib.cycler(color=[my_green, my_copper, "#322B4D", "#28BC9C", "#71074E"])

# %%
def kernel_test(K: Kernel, t_grid, explicit_kernel: Callable):
    fig, ax = plt.subplots(3, 2, figsize=(10, 10))

    K_grid = K(t_grid)
    ax[0, 0].plot(t_grid, K_grid)
    ax[0, 0].plot(t_grid, explicit_kernel(t_grid), "--")
    ax[0, 0].set_title("$K$")

    K_bar_grid = K.integrated_kernel(t_grid)

    ax[0, 1].plot(t_grid, K_bar_grid)
    ax[0, 1].plot(t_grid, cumulative_trapezoid(K_grid, t_grid, initial=0), "--")
    ax[0, 1].set_title("Integrated $K$")

    ax[1, 0].plot(t_grid, K.double_integrated_kernel(t_grid))
    ax[1, 0].plot(t_grid, cumulative_trapezoid(K_bar_grid, t_grid, initial=0), "--")
    ax[1, 0].set_title("Double Integrated $K$")

    try:
        R_grid = K.resolvent(t_grid)
    except NotImplementedError as _:
        R_grid = np.ones_like(t_grid) * np.nan
        warnings.warn(f"The resolvent is not implemented for {K.__class__.__name__}")
    K_mat = np.tril(K(t_grid[:, None] - t_grid[None, :]), k=-1)
    dt = t_grid[1] - t_grid[0]

    ax[1, 1].plot(t_grid, K_mat @ R_grid * dt)
    ax[1, 1].plot(t_grid, R_grid - K_grid, "--")
    ax[1, 1].set_title("Resolvent $K * R = R - K$")
    
    try:
        ax[2, 0].plot(t_grid, K.inv_integrated_kernel(K.integrated_kernel(t_grid)))
    except NotImplementedError as _:
        warnings.warn(f"The inversed integrated kernel is not implemented for {K.__class__.__name__}")
    ax[2, 0].plot(t_grid, t_grid, "--")
    ax[2, 0].set_title(r"$\bar K^{-1}(\bar K(t))$")

    plt.show()

# %% [markdown]
# ## Constant kernel $K(t) = c$

# %%
c = 3

K = ConstantKernel(c=c)

explicit_kernel = lambda t: c * np.ones_like(t)

t_grid = np.linspace(0, 3, 5000)

kernel_test(K=K, t_grid=t_grid, explicit_kernel=explicit_kernel)

# %% [markdown]
# ## Exponential Kernel $K(t) = c e^{-\lambda t}$

# %%
lam = 3
c = lam

K = ExponentialKernel(c=c, lam=lam)

explicit_kernel = lambda t: c * np.exp(-lam * t)

t_grid = np.linspace(0, 3, 5000)

kernel_test(K=K, t_grid=t_grid, explicit_kernel=explicit_kernel)

# %% [markdown]
# ## Sum of exponentials $K(t) = \sum_{i = 1}^N c_i e^{-\lambda_i t} $

# %%
lam = np.array([0.1, 3, 10, 50])
c = np.array([1, 1, 0.5, 0.1])

K = SumOfExponentialKernel(c=c, lam=lam)

explicit_kernel = lambda t: (c[:, None] * np.exp(-lam[:, None] * t[None, :])).sum(axis=0)

t_grid = np.linspace(0, 3, 5000)

kernel_test(K=K, t_grid=t_grid, explicit_kernel=explicit_kernel)
# Out:
# C:\Users\DM6579\AppData\Local\Temp\ipykernel_19384\3061237551.py:34: UserWarning: The inversed integrated kernel is not implemented for SumOfExponentialKernel
#   warnings.warn(f"The inversed integrated kernel is not implemented for {K.__class__.__name__}")

# %% [markdown]
# ## Fractional Kernel $K(t) = c \frac{t^{H-0.5}}{\Gamma(H+0.5)}$

# %%
c, H = 0.5, 0.3

K = FractionalKernel(c=c, H=H)

explicit_kernel = lambda t: c * t**(H - 0.5) / gamma(H + 0.5)

t_grid = np.linspace(0.0001, 3, 10000)

kernel_test(K=K, t_grid=t_grid, explicit_kernel=explicit_kernel)

# %%
eps = 0.2

K = FractionalKernel(c=c, H=H)
K_shifted = ShiftedKernel(eps=eps, kernel=K)

explicit_kernel_shifted = lambda t: explicit_kernel(t + eps)

t_grid = np.linspace(0.0001, 3, 10000)

kernel_test(K=K_shifted, t_grid=t_grid, explicit_kernel=explicit_kernel_shifted)
# Out:
# C:\Users\DM6579\AppData\Local\Temp\ipykernel_19384\3061237551.py:23: UserWarning: The resolvent is not implemented for ShiftedKernel
#   warnings.warn(f"The resolvent is not implemented for {K.__class__.__name__}")

# %% [markdown]
# ## Mittag-Leffler Kernel $K(t) = c t^{\alpha-1} E_{\alpha, \alpha}(ct^{\alpha})$

# %%
c, H = 0.02, 0.3
alpha = H + 0.5

K = MittagLefflerKernel(c=c, alpha=alpha)

explicit_kernel = lambda t:  c * t**(alpha - 1) * mittag_leffler(t=c * t**alpha, alpha=alpha, beta=alpha)

t_grid = np.linspace(0.00001, 3, 1000)

kernel_test(K=K, t_grid=t_grid, explicit_kernel=explicit_kernel)
# Out:
# C:\Users\DM6579\AppData\Local\Temp\ipykernel_19384\3061237551.py:34: UserWarning: The inversed integrated kernel is not implemented for MittagLefflerKernel
#   warnings.warn(f"The inversed integrated kernel is not implemented for {K.__class__.__name__}")

# %% [markdown]
# ## Gamma Kernel $K(t) = c e^{-\lambda x}\frac{t^{H-0.5}}{\Gamma(H+0.5)}$

# %%
alpha, lam = 4, 5
c = 1250 # lam**alpha

K = GammaKernel(c=c, alpha=alpha, lam=lam)

explicit_kernel = lambda t: c * np.exp(-lam * t) * t**(alpha - 1) / gamma(alpha)

t_grid = np.linspace(0.00001, 5, 1000)

kernel_test(K=K, t_grid=t_grid, explicit_kernel=explicit_kernel)

# %% [markdown]
# ## Exp Mittag-Leffler Kernel $K(t) = c e^{-\lambda t}t^{\alpha-1} E_{\alpha, \alpha}(ct^{\alpha})$

# %%
# c, H = 0.02, 0.3
# alpha = H + 0.5
c = 1250
alpha = 4
lam = 5

N=20
K = ExpMittagLefflerKernel(c=c, alpha=alpha, lam=lam, N_mittag_leffler=N)

explicit_kernel = lambda t:  c * np.exp(-lam * t) * t**(alpha - 1) * mittag_leffler(t=c * t**alpha, alpha=alpha, beta=alpha, N=N)

t_grid = np.linspace(0.00001, 5, 1000)

kernel_test(K=K, t_grid=t_grid, explicit_kernel=explicit_kernel)
# Out:
# C:\Users\DM6579\AppData\Local\Temp\ipykernel_19384\3061237551.py:34: UserWarning: The inversed integrated kernel is not implemented for ExpMittagLefflerKernel
#   warnings.warn(f"The inversed integrated kernel is not implemented for {K.__class__.__name__}")
